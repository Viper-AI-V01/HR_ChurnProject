# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('HR.csv')

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='str')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   str
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   str
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df['Attrition']=df['Attrition'].replace({'No':0,'Yes':1})
df['Attrition'] = df['Attrition'].astype('int64')
print(df['Attrition'].dtype)
# Out:
# int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.concat([df['StandardHours'],df['EmployeeCount']],axis=1)
# Out:
#       StandardHours  EmployeeCount
# 0                80              1
# 1                80              1
# 2                80              1
# 3                80              1
# 4                80              1
# ...             ...            ...
# 1465             80              1
# 1466             80              1
# 1467             80              1
# 1468             80              1
# 1469             80              1
#
# [1470 rows x 2 columns]

# %% [markdown]
# #### Insights: Both of the columns 'StandardHours' and 'EmployeeCount' are not useful thus we have to drop both of these columns.

# %%
df =df.drop(columns=['EmployeeCount','StandardHours'])

# %%
df.corr(numeric_only=True)
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.159205   0.010661         -0.001686
# Attrition                -0.159205   1.000000  -0.056652          0.077924
# DailyRate                 0.010661  -0.056652   1.000000         -0.004985
# DistanceFromHome         -0.001686   0.077924  -0.004985          1.000000
# Education                 0.208034  -0.031373  -0.016806          0.021042
# EmployeeNumber           -0.010145  -0.010577  -0.050990          0.032916
# EnvironmentSatisfaction   0.010146  -0.103369   0.018355         -0.016075
# HourlyRate                0.024287  -0.006846   0.023381          0.031131
# JobInvolvement            0.029820  -0.130016   0.046135          0.008783
# JobLevel                  0.509604  -0.169105   0.002966          0.005303
# JobSatisfaction          -0.004892  -0.103481   0.030571         -0.003669
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
cat= [col for col in df.columns if df[col].dtype in ['str','object']]
num =[col for col in df.columns if df[col].dtype not in ['str','object']]
print(f'length {len(cat)}:{cat}',f'\nLenght {len(num)}:{num}')
# Out:
# length 8:['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
# Lenght 25:['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
for values in cat:
    print(f'{values}:{df[values].nunique()}:{df[values].unique().tolist()}')
# Out:
# BusinessTravel:3:['Travel_Rarely', 'Travel_Frequently', 'Non-Travel']
# Department:3:['Sales', 'Research & Development', 'Human Resources']
# EducationField:6:['Life Sciences', 'Other', 'Medical', 'Marketing', 'Technical Degree', 'Human Resources']
# Gender:2:['Female', 'Male']
# JobRole:9:['Sales Executive', 'Research Scientist', 'Laboratory Technician', 'Manufacturing Director', 'Healthcare Representative', 'Manager', 'Sales Representative', 'Research Director', 'Human Resources']
# MaritalStatus:3:['Single', 'Married', 'Divorced']
# Over18:1:['Y']
# OverTime:2:['Yes', 'No']

# %%
df[['BusinessTravel']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='BusinessTravel'>

# %%
df.groupby(['Attrition','BusinessTravel'])['Age'].mean()
# Out:
# Attrition  BusinessTravel
# 0          Non-Travel           36.985507
#            Travel_Frequently    37.653846
#            Travel_Rarely        37.629087
# 1          Non-Travel           32.416667
#            Travel_Frequently    32.840580
#            Travel_Rarely        34.038462
# Name: Age, dtype: float64

# %% [markdown]
# #### Insight: Column = [Over18]
# - Contains only 1 values
# - Therefore we will drop this column

# %%
df = df.drop('Over18',axis=1)

# %%
y = df['Attrition']
X = df.drop('Attrition',axis=1)

# %%
X
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1465   36  Travel_Frequently        884  Research & Development
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                    1          2  Life Sciences               1
# ...

# %%
df_1 = pd.read_csv('Downloaded/employee_churn_dataset.csv')

# %%
df_1.head()
# Out:
#   Employee ID  Age Gender Education Level Marital Status  Tenure Job Role  \
# 0      E00001   50   Male      Bachelor's        Married       5  Analyst
# 1      E00002   36   Male      Bachelor's        Married       4  Manager
# 2      E00003   29   Male      Bachelor's        Married       3    Sales
# 3      E00004   42   Male      Bachelor's         Single      12  Analyst
# 4      E00005   40  Other      Bachelor's        Married       1    Sales
#
#   Department  Salary Work Location  ...  Training Hours  Promotions  \
# 0  Marketing   93422        Remote  ...              35           0
# 1      Sales   44589       On-site  ...               1           0
# 2         IT   56768        Hybrid  ...              41           0
# 3      Sales   79009       On-site  ...              33           0
# 4         HR   81982       On-site  ...              30           0
#
#    Overtime Hours  Satisfaction Level  Work-Life Balance  \
# ...

# %%
df_1.head()
# Out:
#   Employee ID  Age Gender Education Level Marital Status  Tenure Job Role  \
# 0      E00001   50   Male      Bachelor's        Married       5  Analyst
# 1      E00002   36   Male      Bachelor's        Married       4  Manager
# 2      E00003   29   Male      Bachelor's        Married       3    Sales
# 3      E00004   42   Male      Bachelor's         Single      12  Analyst
# 4      E00005   40  Other      Bachelor's        Married       1    Sales
#
#   Department  Salary Work Location  ...  Training Hours  Promotions  \
# 0  Marketing   93422        Remote  ...              35           0
# 1      Sales   44589       On-site  ...               1           0
# 2         IT   56768        Hybrid  ...              41           0
# 3      Sales   79009       On-site  ...              33           0
# 4         HR   81982       On-site  ...              30           0
#
#    Overtime Hours  Satisfaction Level  Work-Life Balance  \
# ...

# %%
df_1.describe()
# Out:
#                 Age        Tenure       Salary  Performance Rating  \
# count  10000.000000  10000.000000   10000.0000          10000.0000
# mean      40.561200      6.976800   89772.7548              3.0275
# std       10.876483      4.296988   34469.8058              1.4120
# min       22.000000      0.000000   30010.0000              1.0000
# 25%       31.000000      3.000000   59718.5000              2.0000
# 50%       41.000000      7.000000   89243.0000              3.0000
# 75%       50.000000     11.000000  119725.5000              4.0000
# max       59.000000     14.000000  149993.0000              5.0000
#
#        Projects Completed  Training Hours    Promotions  Overtime Hours  \
# count        10000.000000    10000.000000  10000.000000      10000.0000
# mean            24.501200       49.715500      0.101000         24.2506
# std             14.444461       28.930822      0.301344         14.4787
# min              0.000000        0.000000      0.000000          0.0000
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Employee ID                   10000 non-null  str
#  1   Age                           10000 non-null  int64
#  2   Gender                        10000 non-null  str
#  3   Education Level               10000 non-null  str
#  4   Marital Status                10000 non-null  str
#  5   Tenure                        10000 non-null  int64
#  6   Job Role                      10000 non-null  str
#  7   Department                    10000 non-null  str
#  8   Salary                        10000 non-null  int64
#  9   Work Location                 10000 non-null  str
#  10  Performance Rating            10000 non-null  int64
#  11  Projects Completed            10000 non-null  int64
#  12  Training Hours                10000 non-null  int64
# ...
